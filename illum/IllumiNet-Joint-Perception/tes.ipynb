# %%
from model.data.dataset import MTLDataset #Dataset
from torch.utils.data import DataLoader


# CONFIGS
model_config = 'model\config\models\yolov8n.yaml'
train_config = 'model\config\training\fine_tune.yaml'

data_train = 'datasets\archive\train'
metadata_train = 'datasets\archive\train_metadata.csv'

data_val = 'datasets\archive\val'
metadata_val = 'datasets\archive\val_metadata.csv'

data_test = 'datasets\archive\test'
metadata_test = 'datasets\archive\test_metadata.csv'
# 

# Data Loading
dataset = MTLDataset(train_config, mode='train')
dataloader = DataLoader(dataset, batch_size=dataset.batch_size, shuffle=True, collate_fn=MTLDataset.collate_fn) #collate_fn=Dataset.collate_fn)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 20
#      16 metadata_test = 'datasets\archive\test_metadata.csv'
#      17 #
#      18
#      19 # Data Loading
# ---> 20 dataset = MTLDataset(train_config, mode='train')
#      21 dataloader = DataLoader(dataset, batch_size=dataset.batch_size, shuffle=True, collate_fn=MTLDataset.collate_fn) #collate_fn=Dataset.collate_fn)
#
# File c:\Users\vian8\Desktop\Tugas2\LLIE\yol_mtl\yolov8\model\data\dataset.py:195, in MTLDataset.__init__(self, config, batch_size, mode, img_size)
#     193 super().__init__()
#     194 # Load config to get the dataset root path
# --> 195 self.config = yaml.safe_load(open(config, 'r'))
#     196 # Base path where the folders (test, train, val) and csvs are located
#     197 self.dataset_path = os.path.join(os.path.dirname(config), self.config['path'])
#
# OSError: [Errno 22] Invalid argument: 'model\\config\training\x0cine_tune.yaml'
